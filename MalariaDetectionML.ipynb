# %% [markdown]
# <a href="https://colab.research.google.com/github/AkritiGhosh/MalariaDetectionML/blob/master/MalariaDetectionML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Malaria Detection using Machine Learning
# This is a basic Machine Learning Model which uses Random Forest classifier to detect malaria.
#
# ###WORKING: -
# It uses images of cells of patients, and on the basis of contour area.
# Cells infected with malaria are distinguished from the healthy one due to the presence of extra spots in the images. The model checks for different boundaries in the image and stores the areas of each ring in a csv file, called area_dataset.csv
#
# This csv file is then used as a structured dataset to be fed into the Random Forest model.

# %% [markdown]
# #  Cell 0: Importing Libraries
# 1. Glob : (Used in Cell 1) the glob module is used to retrieve files/pathnames matching a specified pattern.
#
# 2. OpenCV : (Used in Cell 1) OpenCV is a library of programming functions mainly aimed at real-time computer vision. Reading the image, blurring and contouring of images is done using OpenCV
#
# 3. CSV : (Used in Cell 1 and 2) Library used for creation, manipulation and traversal of csv files.
#
# 4. Pandas :  (Used in Cell 2 and 4) Pandas is used for data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and time series.
#
# 5. Sklearn/ Scikit-Learn :  (Used in Cell 5, 6 and 7) A machine learning library, which features various machine learning models including clustering, regression and classification models. For eg. SVM and Random Forest.
# It also features different metrics for analysis of the created model.

# %%
import glob
import cv2
import csv
import pandas as pd
import io
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
import joblib

# %% [markdown]
# ## Cell 1 : Data Acquisition and Preprocessing
# The following code is the process of reding images from local computer and preprocessing it to give a structured dataset. It has been commented after creation of csv file.
# ###Step 1: Reading images
# The dataset is read from a subdirectory to the current directory called 'cell_images'. Inside it are 2 subfolders named - Parasitized and Uninfected. Each directory files are read, sequentially. The dataset is a collection of cell images with 13,779 infected images and 13,779 healthy cell images.
# ###Step 2: Grayscale and Blurring
# Since, color is not an important factor in this classification, the image, after reading are converted into grayscale; and is blurred using Gaussian Blur to remove unnecessary noise.
# ###Step 3: Finding contours and their areas
# Threshold() is used to fix some value which draws a boundary line between two set of data. From this boundary, contours are found and their areas are evaluated.
#
# This area is now stored in separate csv files for Infected and Uninfected images.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !unzip '/content/drive/My Drive/cell_images.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_118.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_126.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_134.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_141.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_168.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_175.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_183.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_221.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_222.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_87.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102428_cell_91.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_104.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_13.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_146.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_168.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_177.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_179.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_186.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_20.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_219.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_236.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_251.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_254.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_33.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102516_cell_58.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_111.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_134.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_160.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_164.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_169.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_171.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_18.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_180.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_187.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_199.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_208.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_32.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_48.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102546_cell_89.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_127.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_143.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_196.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_206.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_209.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_253.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_254.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_26.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_46.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_8.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_84.png
#  extracting: cell_images/Uninfected/C236ThinF_IMG_20151127_102635_cell_88.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_110.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_126.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_152.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_16.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_167.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_168.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_169.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_178.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_18.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_184.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_4.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_43.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_67.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104748_cell_88.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_12.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_129.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_138.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_154.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_158.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_17.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_199.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_222.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_244.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_245.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_56.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_63.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_72.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104844_cell_99.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_11.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_119.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_128.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_146.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_162.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_200.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_225.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_25.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_38.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_40.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_45.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_54.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_76.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_104954_cell_80.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_11.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_120.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_131.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_148.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_151.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_165.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_220.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_235.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_259.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_38.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_47.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_67.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105320_cell_93.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_100.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_103.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_105.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_153.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_172.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_18.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_228.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_24.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_259.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_35.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_38.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_73.png
#  extracting: cell_images/Uninfected/C237ThinF_IMG_20151127_105345_cell_96.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_106.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_109.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_120.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_139.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_170.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_192.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_201.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_36.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_84.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114038_cell_97.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_103.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_115.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_164.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_179.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_189.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_30.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_46.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_55.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_59.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114345_cell_84.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_127.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_133.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_141.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_159.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_28.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_32.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_41.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_65.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_90.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114444_cell_91.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_123.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_151.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_163.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_164.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_171.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_18.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_24.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_64.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_75.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114605_cell_83.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_106.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_120.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_125.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_126.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_13.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_133.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_148.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_154.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_58.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114653_cell_95.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_165.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_174.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_180.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_190.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_26.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_36.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_40.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_42.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_51.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_114914_cell_91.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_115.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_148.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_172.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_184.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_187.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_188.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_191.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_25.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_41.png
#  extracting: cell_images/Uninfected/C238NThinF_IMG_20151207_115017_cell_95.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_1.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_127.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_146.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_154.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_162.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_174.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_202.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_215.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_216.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_279.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_39.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_60.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_71.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113008_cell_76.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_128.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_130.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_17.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_174.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_178.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_181.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_196.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_225.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_24.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_262.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_3.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_54.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_71.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113150_cell_82.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_12.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_164.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_199.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_216.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_237.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_244.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_250.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_26.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_265.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_273.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_291.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_62.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113202_cell_91.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_116.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_117.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_123.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_132.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_173.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_23.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_236.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_237.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_245.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_284.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_38.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_61.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_7.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113223_cell_96.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113253_cell_148.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113253_cell_150.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113253_cell_169.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113253_cell_18.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113253_cell_188.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113253_cell_25.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113253_cell_254.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113253_cell_278.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113253_cell_61.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113253_cell_67.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113253_cell_73.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113253_cell_80.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113253_cell_84.png
#  extracting: cell_images/Uninfected/C239ThinF_IMG_20151127_113253_cell_94.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115223_cell_105.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115223_cell_106.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115223_cell_120.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115223_cell_121.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115223_cell_125.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115223_cell_144.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115223_cell_167.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115223_cell_182.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115223_cell_185.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115223_cell_194.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115223_cell_72.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115223_cell_87.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115223_cell_9.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115247_cell_151.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115247_cell_160.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115247_cell_17.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115247_cell_203.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115247_cell_205.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115247_cell_208.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115247_cell_234.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115247_cell_42.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115247_cell_5.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115247_cell_64.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115247_cell_96.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115247_cell_97.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115306_cell_105.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115306_cell_110.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115306_cell_172.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115306_cell_203.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115306_cell_231.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115306_cell_29.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115306_cell_4.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115306_cell_6.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115306_cell_73.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115306_cell_75.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115306_cell_92.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115306_cell_96.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115328_cell_104.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115328_cell_15.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115328_cell_157.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115328_cell_159.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115328_cell_16.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115328_cell_166.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115328_cell_192.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115328_cell_196.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115328_cell_200.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115328_cell_225.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115328_cell_227.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115328_cell_65.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115328_cell_7.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115328_cell_72.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115545_cell_127.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115545_cell_129.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115545_cell_138.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115545_cell_140.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115545_cell_174.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115545_cell_205.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115545_cell_207.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115545_cell_214.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115545_cell_28.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115545_cell_42.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115545_cell_44.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115545_cell_6.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115545_cell_63.png
#  extracting: cell_images/Uninfected/C240ThinF_IMG_20151127_115545_cell_97.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124030_cell_129.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124030_cell_142.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124030_cell_143.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124030_cell_144.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124030_cell_15.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124030_cell_150.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124030_cell_20.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124030_cell_43.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124030_cell_83.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124030_cell_98.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124115_cell_138.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124115_cell_143.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124115_cell_161.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124115_cell_166.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124115_cell_173.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124115_cell_26.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124115_cell_29.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124115_cell_75.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124115_cell_87.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124208_cell_112.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124208_cell_117.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124208_cell_119.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124208_cell_128.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124208_cell_132.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124208_cell_150.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124208_cell_164.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124208_cell_29.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124208_cell_68.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124208_cell_7.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124240_cell_125.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124240_cell_131.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124240_cell_149.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124240_cell_169.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124240_cell_18.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124240_cell_51.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124240_cell_6.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124240_cell_7.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124240_cell_9.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124358_cell_119.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124358_cell_130.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124358_cell_137.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124358_cell_144.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124358_cell_149.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124358_cell_35.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124358_cell_73.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124358_cell_82.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124358_cell_84.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124358_cell_91.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124608_cell_104.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124608_cell_120.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124608_cell_125.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124608_cell_171.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124608_cell_22.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124608_cell_30.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124608_cell_40.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124608_cell_51.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124608_cell_61.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124608_cell_90.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124643_cell_125.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124643_cell_136.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124643_cell_158.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124643_cell_169.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124643_cell_25.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124643_cell_26.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124643_cell_45.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124643_cell_46.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124643_cell_91.png
#  extracting: cell_images/Uninfected/C241NThinF_IMG_20151207_124643_cell_96.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114631_cell_141.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114631_cell_144.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114631_cell_150.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114631_cell_155.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114631_cell_187.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114631_cell_204.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114631_cell_214.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114631_cell_215.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114631_cell_38.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114631_cell_52.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114631_cell_72.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114631_cell_74.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114631_cell_84.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114631_cell_99.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114730_cell_113.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114730_cell_12.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114730_cell_124.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114730_cell_13.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114730_cell_139.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114730_cell_161.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114730_cell_172.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114730_cell_173.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114730_cell_178.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114730_cell_183.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114730_cell_36.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114730_cell_72.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114730_cell_98.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114751_cell_101.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114751_cell_106.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114751_cell_107.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114751_cell_113.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114751_cell_127.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114751_cell_142.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114751_cell_181.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114751_cell_197.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114751_cell_217.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114751_cell_221.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114751_cell_38.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114751_cell_69.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114751_cell_92.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114751_cell_93.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114815_cell_107.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114815_cell_128.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114815_cell_142.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114815_cell_217.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114815_cell_232.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114815_cell_233.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114815_cell_235.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114815_cell_242.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114815_cell_6.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114815_cell_62.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114815_cell_66.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114815_cell_73.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114815_cell_9.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_114815_cell_95.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_115238_cell_115.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_115238_cell_117.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_115238_cell_126.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_115238_cell_13.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_115238_cell_133.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_115238_cell_138.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_115238_cell_196.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_115238_cell_203.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_115238_cell_205.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_115238_cell_223.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_115238_cell_240.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_115238_cell_247.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_115238_cell_249.png
#  extracting: cell_images/Uninfected/C2NThinF_IMG_20150604_115238_cell_259.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_114756a_cell_127.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_114756a_cell_157.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_114756a_cell_2.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_114756a_cell_20.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_114756a_cell_36.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_114756a_cell_81.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_115740a_cell_120.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_115740a_cell_127.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_115740a_cell_132.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_115740a_cell_39.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_115740a_cell_6.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_115740a_cell_65.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_115808a_cell_101.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_115808a_cell_175.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_115808a_cell_52.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_115808a_cell_55.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_115808a_cell_59.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_115808a_cell_62.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120645a_cell_11.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120645a_cell_153.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120645a_cell_189.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120645a_cell_212.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120645a_cell_26.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120645a_cell_35.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120742a_cell_120.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120742a_cell_123.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120742a_cell_155.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120742a_cell_182.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120742a_cell_191.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120742a_cell_62.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120804a_cell_166.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120804a_cell_3.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120804a_cell_55.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120804a_cell_65.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120804a_cell_73.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120804a_cell_74.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120838a_cell_105.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120838a_cell_134.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120838a_cell_28.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120838a_cell_42.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120838a_cell_91.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_120838a_cell_94.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121102a_cell_156.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121102a_cell_159.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121102a_cell_176.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121102a_cell_60.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121102a_cell_62.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121102a_cell_7.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121229a_cell_120.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121229a_cell_127.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121229a_cell_144.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121229a_cell_42.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121229a_cell_46.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121229a_cell_97.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121300a_cell_129.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121300a_cell_135.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121300a_cell_151.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121300a_cell_29.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121300a_cell_46.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121300a_cell_67.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121411a_cell_102.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121411a_cell_114.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121411a_cell_139.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121411a_cell_43.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121411a_cell_78.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121411a_cell_79.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121435a_cell_138.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121435a_cell_147.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121435a_cell_35.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121435a_cell_41.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121435a_cell_98.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121503a_cell_105.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121503a_cell_143.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121503a_cell_72.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121503a_cell_73.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121503a_cell_76.png
#  extracting: cell_images/Uninfected/C33P1thinF_IMG_20150619_121503a_cell_99.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_131423a_cell_10.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_131423a_cell_16.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_131423a_cell_38.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_131423a_cell_41.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_131423a_cell_47.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_131423a_cell_51.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_131423a_cell_63.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_131423a_cell_67.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_131423a_cell_87.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132440a_cell_1.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132440a_cell_25.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132440a_cell_41.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132440a_cell_44.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132440a_cell_50.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132440a_cell_54.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132440a_cell_61.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132440a_cell_62.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132440a_cell_82.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132440a_cell_89.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132847a_cell_1.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132847a_cell_18.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132847a_cell_37.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132847a_cell_38.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132847a_cell_42.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132847a_cell_50.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132847a_cell_51.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132847a_cell_60.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132847a_cell_7.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_132847a_cell_75.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133001a_cell_12.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133001a_cell_2.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133001a_cell_20.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133001a_cell_44.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133001a_cell_45.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133001a_cell_64.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133001a_cell_66.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133001a_cell_67.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133001a_cell_68.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133001a_cell_7.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133111a_cell_16.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133111a_cell_31.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133111a_cell_4.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133111a_cell_40.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133111a_cell_46.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133111a_cell_59.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133111a_cell_64.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133111a_cell_69.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133111a_cell_75.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133111a_cell_81.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133205a_cell_18.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133205a_cell_38.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133205a_cell_41.png
#  extracting: cell_images/Uninfected/C37BP2_thinF_IMG_20150620_133205a_cell_58.png
# ...
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_145555_cell_88.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_145555_cell_94.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_150838_cell_108.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_150838_cell_118.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_150838_cell_124.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_150838_cell_13.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_150838_cell_145.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_150838_cell_47.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_150838_cell_57.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_150838_cell_82.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151320_cell_102.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151320_cell_11.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151320_cell_113.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151320_cell_119.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151320_cell_142.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151320_cell_26.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151320_cell_51.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151320_cell_54.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151437_cell_113.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151437_cell_18.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151437_cell_29.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151437_cell_32.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151437_cell_55.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151437_cell_63.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151437_cell_67.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151437_cell_71.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151437_cell_77.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151512_cell_110.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151512_cell_112.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151512_cell_116.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151512_cell_117.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151512_cell_133.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151512_cell_134.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151512_cell_146.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151512_cell_16.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151512_cell_26.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151512_cell_7.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151551_cell_105.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151551_cell_134.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151551_cell_142.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151551_cell_147.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151551_cell_2.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151551_cell_41.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151551_cell_47.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151551_cell_56.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151551_cell_57.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_151551_cell_99.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_152032_cell_1.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_152032_cell_101.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_152032_cell_104.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_152032_cell_128.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_152032_cell_143.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_152032_cell_42.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_152032_cell_44.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_152032_cell_6.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_152032_cell_62.png
#  extracting: cell_images/Uninfected/C97P58ThinF_IMG_20150917_152032_cell_93.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153030_cell_120.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153030_cell_136.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153030_cell_144.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153030_cell_28.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153030_cell_30.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153030_cell_62.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153030_cell_74.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153030_cell_8.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153030_cell_95.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153311_cell_118.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153311_cell_143.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153311_cell_149.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153311_cell_16.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153311_cell_27.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153311_cell_32.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153311_cell_49.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153311_cell_61.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153311_cell_73.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153600_cell_1.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153600_cell_116.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153600_cell_125.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153600_cell_130.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153600_cell_152.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153600_cell_160.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153600_cell_184.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153600_cell_21.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153600_cell_27.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153600_cell_5.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153600_cell_83.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153801_cell_1.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153801_cell_127.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153801_cell_141.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153801_cell_176.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153801_cell_178.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153801_cell_58.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153801_cell_59.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153801_cell_64.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153801_cell_79.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153801_cell_83.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153938_cell_10.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153938_cell_100.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153938_cell_111.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153938_cell_117.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153938_cell_130.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153938_cell_165.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153938_cell_170.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153938_cell_26.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153938_cell_44.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_153938_cell_6.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154235_cell_125.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154235_cell_128.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154235_cell_135.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154235_cell_143.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154235_cell_157.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154235_cell_171.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154235_cell_20.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154235_cell_30.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154235_cell_85.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154235_cell_86.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154452_cell_102.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154452_cell_108.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154452_cell_111.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154452_cell_144.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154452_cell_19.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154452_cell_199.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154452_cell_33.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154452_cell_44.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154452_cell_70.png
#  extracting: cell_images/Uninfected/C98P59ThinF_IMG_20150917_154452_cell_99.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_140900_cell_24.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_140900_cell_34.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_140900_cell_41.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_140900_cell_44.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_140900_cell_52.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_140900_cell_59.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_140900_cell_6.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_140900_cell_66.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_140900_cell_69.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_140900_cell_91.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141001_cell_24.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141001_cell_26.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141001_cell_4.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141001_cell_46.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141001_cell_50.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141001_cell_60.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141001_cell_61.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141001_cell_66.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141001_cell_69.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141001_cell_89.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141129_cell_15.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141129_cell_20.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141129_cell_21.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141129_cell_3.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141129_cell_38.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141129_cell_75.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141129_cell_77.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141129_cell_8.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141129_cell_84.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141129_cell_86.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141314_cell_11.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141314_cell_16.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141314_cell_31.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141314_cell_39.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141314_cell_46.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141314_cell_57.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141314_cell_65.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141314_cell_77.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141314_cell_79.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141314_cell_81.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141351_cell_22.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141351_cell_26.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141351_cell_53.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141351_cell_56.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141351_cell_75.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141351_cell_83.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141351_cell_92.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141520_cell_1.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141520_cell_16.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141520_cell_17.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141520_cell_22.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141520_cell_31.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141520_cell_38.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141520_cell_42.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141520_cell_45.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141520_cell_64.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141520_cell_73.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_141520_cell_9.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_142128_cell_11.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_142128_cell_14.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_142128_cell_15.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_142128_cell_3.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_142128_cell_45.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_142128_cell_47.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_142128_cell_52.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_142128_cell_53.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_142128_cell_55.png
#  extracting: cell_images/Uninfected/C99P60ThinF_IMG_20150918_142128_cell_56.png
#   inflating: cell_images/Uninfected/Thumbs.db

# %%
### Dataset(CSV) creation using Cell Images => Unstructured to Structured

## Reading image path
name = 'Uninfected'
name = 'Parasitized'
for name in ['Uninfected', 'Parasitized']
  img_path_infected = glob.glob('cell_images/'+name+'/*.png')

  ## For every image in this path
  for img_name in img_path_infected:
    print(img_name)
      ## Read images
    img = cv2.imread(img_name)

      ## Gaussian Blur - Noise removal
    img = cv2.GaussianBlur(img,(5,5),0)
      ## Conversion to Grayscale
    im_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
      
      ## Color Thresholding
    ret,thresh = cv2.threshold(im_gray,127,255,0)
      ## Contour detection
    contours,_ = cv2.findContours(thresh,1,2)
    for contour in contours:
        cv2.drawContours(im_gray, contours, -1, (0,255,0), 3)
        print(contour)
    
      ## Saving the area of contours in csv file
    with open('area.csv', mode ='a') as contour_list:
        fieldnames = ['file_name', 'area1', 'area2', 'area3', 'area4', 'area5']
        area=[]
        for i in range(5):
            try:
                area.append(cv2.contourArea(contours[i]))
            except:
                area.append('0')
    
        writer = csv.DictWriter(contour_list, fieldnames=fieldnames)
        writer.writerow({'file_name':name, 'area1':area[0], 'area2':area[1], 'area3':area[2], 'area4':area[3], 'area5':area[4]})

# %% [markdown]
# # Cell 2: Merging the CSV files
# Two separate csv files were created for each of the classes - Parasitized and Uninfected. These files are merged together to form a single csv file.
#
# The following code reads all csv files in the given location and concatinates it into a single file called area_dataset.csv

# %%
# ### Merging different csv (ie infected.csv and uninfected.csv) files into a single file (area_dataset.csv)

# extension = 'csv'
# all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
# #combine all files in the list
# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# #export to csv
# combined_csv.to_csv( "area_dataset.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# # Cell 3 : Uploading file from local computer to google colab
# This process is used to select a file from local computer and save it in a variable. This will store the csv file which will be converted to a Pandas Dataframe.
#
# It is used in Google Colab, not necessary in a jupyter notebook or any other IDEs.

# %%
### reading dataset/csv  in Google Colab
from google.colab import files
uploaded = files.upload()
print(type(uploaded))
# Out:
#      <input type="file" id="files-a12a72f1-a4c5-4aa7-8587-9d8b433a4717" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a12a72f1-a4c5-4aa7-8587-9d8b433a4717">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
# !unzip

# %% [markdown]
# # Cell 4 : Creation of Pandas Dataframe
# The csv file is read and stored as a Pandas dataframe. When working in platforms other than Colab, use
#
# `*data = pd.read("location_of_file/filename.csv")*`

# %%
data = pd.read_csv(io.StringIO(uploaded['area_dataset.csv'].decode('utf-8')))
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # Cell 5 : Dataset Split
# The dataset is split into 2 parts : -
# 1. x - the features i.e. the areas of contours
# 2. y - the labels or classes
#
# The format of the dataset is -
# Label ; area1  ; area2 ;   area3 ;  area4  ; area5
#
# The 1st columns (Label) is **'y'** and the remaining is **'x'**
#
# The dataset is also split into training and testing dataset with the ratio of 75% and 25% respectively.

# %%
x = data.drop(["Label"], axis=1)
y = data["Label"]
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.25, random_state = 4)

# %% [markdown]
# # Cell 6 : Training the model
# The model used for this classification is Random Forest Classifier. Model creation is a lot easier using the sklearn library. Parameter are set accordingly.
# Then the model is trained using the training dataset (x_train, y_train)

# %%
model = RandomForestClassifier(n_estimators=100, max_depth=5)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=5, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# # Cell 7 : Model testing and Predictions
# The model is tested against the testing dataset and the predicted values are stored in y_predict.
#
# These predictions are then tested against the actual values of the testing dataset, to evaluate the accuracy of the model.
# The model is showing an accuracy of 90%
#
# The model can be saved if required, using joblib.dump().

# %%
y_predict = model.predict(x_test)
accuracy = metrics.classification_report(y_predict, y_test)
print(accuracy)
# Out:
#               precision    recall  f1-score   support
#
#  Parasitized       0.90      0.89      0.90      3428
#   Uninfected       0.89      0.91      0.90      3462
#
#     accuracy                           0.90      6890
#    macro avg       0.90      0.90      0.90      6890
# weighted avg       0.90      0.90      0.90      6890
